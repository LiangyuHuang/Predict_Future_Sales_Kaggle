# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('submission.csv')

# %%
df.describe()
# Out:
#                   ID  item_cnt_month
# count  214200.000000   214200.000000
# mean   107099.500000        0.313401
# std     61834.358168        0.837937
# min         0.000000        0.000000
# 25%     53549.750000        0.030813
# 50%    107099.500000        0.088108
# 75%    160649.250000        0.274192
# max    214199.000000       20.000000

# %%
plt.rcParams["font.sans-serif"]='Times New Roman'
plt.rcParams['axes.unicode_minus']=False
# %config InlineBackend.figure_format='svg'

plt.hist(x=df['item_cnt_month'],bins=20,color="steelblue",edgecolor="none", alpha=0.75)

plt.xlabel("dataset")
plt.ylabel("count")

plt.title("frequency distribution")

plt.show()
